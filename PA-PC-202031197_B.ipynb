# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
from google.colab.patches import cv2_imshow
from google.colab import files
import numpy as np
import matplotlib.pyplot as alt

# %%
from google.colab.patches import cv2_imshow

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks')

# %%
img = cv2.imread("nanass.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=433x577>

# %%
# Import pustaka yang diperlukan
from PIL import Image
import matplotlib.pyplot as plt

# Pastikan Anda mengunggah gambar ke dalam notebook terlebih dahulu

# Misalkan nama file gambar yang di-upload adalah 'gambar.jpg'
img_path = 'nanass.jpg'  # Sesuaikan nama file dengan file yang di-upload

# Membaca gambar menggunakan PIL
img = Image.open(img_path)

# Menampilkan gambar asli
plt.figure(figsize=(6, 6))
plt.imshow(img)
plt.title('Citra Asli')
plt.axis('on')
plt.show()

# %%
buah = cv2.imread("nanass.jpg", 1)
tinggi, lebar, channels = buah.shape
print(f"Tinggi: {tinggi}, Lebar: {lebar}, Channels: {channels}")
# Out:
# Tinggi: 577, Lebar: 433, Channels: 3

# %%
cv2_imshow(buah)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=433x577>

# %% [markdown]
# Mask Mangga

# %%
# Mengkonversi gambar berwarna menjadi grayscale
buah_gray = cv2.cvtColor(buah, cv2.COLOR_BGR2GRAY)

# Mendapatkan dimensi gambar grayscale
tinggi, lebar = buah_gray.shape
cv2_imshow(buah_gray)
# Out:
# <PIL.Image.Image image mode=L size=433x577>

# %%
def arasjamak(image, t1, t2):
    # Pastikan gambar adalah grayscale, jika tidak, konversi ke grayscale
    if len(image.shape) == 3 and image.shape[2] == 3:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Mendapatkan dimensi gambar
    m, n = image.shape

    # Melakukan thresholding
    res = np.zeros((m, n), dtype=np.uint8)
    for x in range(m):
        for y in range(n):
            if image[x, y] < t1:
                res[x, y] = 0
            elif image[x, y] > t2:
                res[x, y] = 255
            else:
                res[x, y] = 128

    return res

# %%
res = arasjamak(buah, 175, 220)

# %%
cv2_imshow(res)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=433x577>

# %%
# Load image
img = cv2.imread("nanass.jpg")

# Convert to HSV
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# Define range of yellow color in HSV
lower_yellow = np.array([20, 100, 100])
upper_yellow = np.array([30, 255, 255])

# Threshold the HSV image to get only yellow colors
mask = cv2.inRange(hsv, lower_yellow, upper_yellow)

# Bitwise-AND mask and original image
res = cv2.bitwise_and(img,img, mask= mask)

# Convert the result to grayscale
gray = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)

# Set non-masked pixels to white (255)
gray[gray != 0] = 255

# Display the result
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=433x577>

# %%
# Load image
img = cv2.imread("nanass.jpg")

# Convert to HSV
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# Define range of yellow color in HSV
lower_yellow = np.array([20, 100, 100])
upper_yellow = np.array([30, 255, 255])

# Threshold the HSV image to get only yellow colors
mask = cv2.inRange(hsv, lower_yellow, upper_yellow)

# Bitwise-AND mask and original image
res = cv2.bitwise_and(img, img, mask=mask)

# Display the result
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=RGB size=433x577>

# %%
# Load image
img = cv2.imread("nanass.jpg")

# Convert to HSV
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# Define range of green color in HSV
lower_green = np.array([35, 50, 50])
upper_green = np.array([85, 255, 255])

# Threshold the HSV image to get only green colors
mask = cv2.inRange(hsv, lower_green, upper_green)

# Bitwise-AND mask and original image
res = cv2.bitwise_and(img, img, mask=mask)

# Display the result
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=RGB size=433x577>

# %%
# Load image
img = cv2.imread("nanass.jpg")

# Convert to HSV
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# Define range of yellow color in HSV
lower_yellow = np.array([20, 100, 100])
upper_yellow = np.array([30, 255, 255])

# Threshold the HSV image to get only yellow colors
mask_yellow = cv2.inRange(hsv, lower_yellow, upper_yellow)

# Bitwise-AND mask and original image for yellow
res_yellow = cv2.bitwise_and(img, img, mask=mask_yellow)

# Define range of green color in HSV
lower_green = np.array([35, 50, 50])
upper_green = np.array([85, 255, 255])

# Threshold the HSV image to get only green colors
mask_green = cv2.inRange(hsv, lower_green, upper_green)

# Bitwise-AND mask and original image for green
res_green = cv2.bitwise_and(img, img, mask=mask_green)

# Convert the yellow result to grayscale
gray = cv2.cvtColor(res_yellow, cv2.COLOR_BGR2GRAY)

# Set non-masked pixels to white (255)
gray[gray != 0] = 255

# Create a 2x2 subplot
plt.figure(figsize=(12, 12))

# Original Image
plt.subplot(2, 2, 1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Citra Asli')
plt.axis('on')

# White Mask
plt.subplot(2, 2, 2)
plt.imshow(gray, cmap='gray')
plt.title('Mask Buah Nanas (Putih)')
plt.axis('on')

# Yellow Pineapple
plt.subplot(2, 2, 3)
plt.imshow(cv2.cvtColor(res_yellow, cv2.COLOR_BGR2RGB))
plt.title('Tampilan Nanas (Kuning)')
plt.axis('on')

# Green Leaves
plt.subplot(2, 2, 4)
plt.imshow(cv2.cvtColor(res_green, cv2.COLOR_BGR2RGB))
plt.title('Tampilan Daun (Hijau)')
plt.axis('on')

plt.show()
